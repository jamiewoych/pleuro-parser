# %%
#show and tell
mini_project -n 10 -v
mini_project -h
mini_project -f "salamander_inventory.csv" -m "SAL_003" "Rack 2"
mini_project -f "salamander_inventory.csv" -e "SAL_004" "2025-03-12" "7" "M" "histology" "JW" "None"
cat euthanasia_f

# %%
#To run flask app locally to test
python app.py
#This will start the api at
http://127.0.0.1:5000/api
curl -X GET http://127.0.0.1:5000/api/salamanders

# 127.0.0.1 (or localhost) is your own computer running the Flask API.
# 5000 is the default port where Flask runs.
# /api/salamanders is the API route you need to define in your Flask app.

Before running the API, initialize the database: 
bash 
CopyEdit 

python >>> from app import db >>> db.create_all()  

This creates the SQLite database file (salamander_inventory.db).

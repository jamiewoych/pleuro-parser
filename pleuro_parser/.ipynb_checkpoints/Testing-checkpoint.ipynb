# %%
import sys
sys.path.append('..')
import module
import pandas as pd

# %%
R = module.Rack(inventory_file = "salamander_inventory.csv", filename = "current.csv", euthanasia_log_file = "euthanasia_log.csv")
# Out:
# Temporary session directory created at <TemporaryDirectory '/var/folders/qk/0pp_4zdn44s_7tprcl4npjfw0000gn/T/tmp2qwq5mow'>
# Loaded existing inventory from salamander_inventory.csv
# Loading existing inventory from Larval_Clutches.csv
# State saved: 1 states in history.

# %%
R.plot_rack_space()

# %%
R.get_dob_options()
# Out:
# array(['10/25/24', '11/25/24', '12/10/24', '1/3/25'], dtype=object)

# %%
R.inventory
# Out:
#     Animal_ID Tank     Rack         DOB                    Cohort  \
# 0     SAL_003   C4  Rack 12         NaN  Reptile Rapture - Yellow
# 1     SAL_004   C4  Rack 12     1/21/20  Reptile Rapture - Yellow
# 2     SAL_005   C4  Rack 12     1/21/20  Reptile Rapture - Yellow
# 3     SAL_006   C4  Rack 12     1/21/20  Reptile Rapture - Yellow
# 4     SAL_007   B4  Rack 12     1/21/20      Reptiles & Critters
# ..        ...  ...      ...         ...                       ...
# 724   SAL_734   C4  Rack 12  2020/01/21                       NaN
# 725   SAL_735   C4  Rack 12  2020/01/21                       NaN
# 726   SAL_736   C4  Rack 12  2020/01/21                       NaN
# 727   SAL_737   C4  Rack 12  2020/01/21                       NaN
# 728   SAL_738   C4  Rack 12  2020/01/21                       NaN
#
#     Environmental_Condition     Sex Lineage Transgenic_Line  \
# 0                   Aquatic  Female     NaN              WT
# 1                   Aquatic    Male     NaN              WT
# 2                   Aquatic    Male     NaN              WT
# 3                   Aquatic    Male     NaN              WT
# 4                   Aquatic    Male     NaN              WT
# ..                      ...     ...     ...             ...
# 724                 Aquatic  Female    fake              WT
# 725                 Aquatic  Female    fake              WT
# 726                 Aquatic  Female    fake              WT
# 727                 Aquatic  Female    fake              WT
# 728                 Aquatic  Female    fake              WT
#
#     Experimental_Holds            Species Protocol_Number  \
# 0             Breeding  Pleurodeles waltl        AABF2564
# 1             Breeding  Pleurodeles waltl        AABF2564
# 2             Breeding  Pleurodeles waltl        AABF2564
# 3             Breeding  Pleurodeles waltl        AABF2564
# 4             Breeding  Pleurodeles waltl        AABF2564
# ..                 ...                ...             ...
# 724         No history  Pleurodeles waltl        AABF2564
# 725         No history  Pleurodeles waltl        AABF2564
# 726         No history  Pleurodeles waltl        AABF2564
# 727         No history  Pleurodeles waltl        AABF2564
# 728         No history  Pleurodeles waltl        AABF2564
#
#     Experimental_History        RFID Date_of_Terra Date_of_Reaqua Diet
# 0                    NaN         NaN           NaN            NaN  NaN
# 1                    NaN         NaN           NaN            NaN  NaN
# 2                    NaN         NaN           NaN            NaN  NaN
# 3                    NaN         NaN           NaN            NaN  NaN
# 4                    NaN         NaN           NaN            NaN  NaN
# ..                   ...         ...           ...            ...  ...
# 724                 rifd  2025-05-04    2025-04-03     Gummy diet  NaN
# 725                 rifd  2025-05-04    2025-04-03     Gummy diet  NaN
# 726                 rifd  2025-05-04    2025-04-03     Gummy diet  NaN
# 727                 rifd  2025-05-04    2025-04-03     Gummy diet  NaN
# 728                 rifd  2025-05-04    2025-04-03     Gummy diet  NaN
#
# [729 rows x 17 columns]

# %%
R.add_salamanders(3, "2020/01/21", "Pleurodeles waltl", "WT", "fake", "AABF2564", "Rack 12", "C4", "Aquatic", "Female", "NA","No history", "rifd", "2025-05-04", "2025-04-03", "Gummy diet")
# Out:
# 3 new salamander(s) adding successfully.
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.
# State saved: 2 states in history.
# Log successful
# ['SAL_739', 'SAL_740', 'SAL_741'] salamanders added to Rack 12, tank C4, with DOB 2020/01/21.
# ['SAL_739', 'SAL_740', 'SAL_741']

# %%
R.euthanize_animal('SAL_740','2025-4-12', 9, "Male", "Histology", "AOG", complications="found dead")
# Out:
# Log successful
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.
# State saved: 3 states in history.
# Animal SAL_740 euthanized and removed from inventory.
# True

# %%
R.undo() #change_types: Edit, Undo, Add, Move, Euthanize
# Out:
# No previous state to undo.
# False

# %%
print(f"Current history: {R.history}")
# Out:
# Current history: [    Animal_ID Tank     Rack                  DOB                    Cohort  \
# 0     SAL_003   C4  Rack 12                  NaN  Reptile Rapture - Yellow
# 1     SAL_004   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 2     SAL_005   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 3     SAL_006   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 4     SAL_007   B4  Rack 12              1/21/20      Reptiles & Critters
# ..        ...  ...      ...                  ...                       ...
# 718   SAL_728   C4   Rack 5  2024-12-10 00:00:00                       NaN
# 719   SAL_729   C4   Rack 5  2024-12-10 00:00:00                       NaN
# 720   SAL_730   C3   Rack 1  2025-03-12 00:00:00                       NaN
# 721   SAL_731   C3   Rack 1  2025-03-12 00:00:00                       NaN
# 722   SAL_732   A1   Rack 1                  NaN                       NaN
#
#     Environmental_Condition      Sex Lineage Transgenic_Line  \
# 0                   Aquatic   Female     NaN              WT
# 1                   Aquatic     Male     NaN              WT
# 2                   Aquatic     Male     NaN              WT
# 3                   Aquatic     Male     NaN              WT
# 4                   Aquatic     Male     NaN              WT
# ..                      ...      ...     ...             ...
# 718                 Aquatic  Unknown     NaN              WT
# 719                 Aquatic  Unknown     NaN              WT
# 720                 Aquatic  Unknown     NaN              WT
# 721                 Aquatic  Unknown     NaN              WT
# 722                 Aquatic  Unknown     NaN              WT
#
#     Experimental_Holds               Species Protocol_Number  \
# 0             Breeding     Pleurodeles waltl        AABF2564
# 1             Breeding     Pleurodeles waltl        AABF2564
# 2             Breeding     Pleurodeles waltl        AABF2564
# 3             Breeding     Pleurodeles waltl        AABF2564
# 4             Breeding     Pleurodeles waltl        AABF2564
# ..                 ...                   ...             ...
# 718                NaN     Pleurodeles waltl        AABF2564
# 719                NaN     Pleurodeles waltl        AABF2564
# 720                 GG  Polypterus senegalus        AABY5655
# 721                 GG  Polypterus senegalus        AABY5655
# 722                NaN     Pleurodeles waltl        AABL1550
#
#     Experimental_History RFID Date_of_Terra  Date_of_Reaqua Diet
# 0                    NaN  NaN           NaN             NaN  NaN
# 1                    NaN  NaN           NaN             NaN  NaN
# 2                    NaN  NaN           NaN             NaN  NaN
# 3                    NaN  NaN           NaN             NaN  NaN
# 4                    NaN  NaN           NaN             NaN  NaN
# ..                   ...  ...           ...             ...  ...
# 718                  NaN  NaN           NaN             NaN  NaN
# 719                  NaN  NaN           NaN             NaN  NaN
# 720                  NaN  NaN           NaN             NaN  NaN
# 721                  NaN  NaN           NaN             NaN  NaN
# 722                  NaN  NaN           NaN             NaN  NaN
#
# [723 rows x 17 columns],     Animal_ID Tank     Rack                  DOB                    Cohort  \
# 0     SAL_003   C4  Rack 12                  NaN  Reptile Rapture - Yellow
# 1     SAL_004   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 2     SAL_005   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 3     SAL_006   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 4     SAL_007   B4  Rack 12              1/21/20      Reptiles & Critters
# ..        ...  ...      ...                  ...                       ...
# 721   SAL_731   C3   Rack 1  2025-03-12 00:00:00                       NaN
# 722   SAL_732   A1   Rack 1                  NaN                       NaN
# 723   SAL_733   C4  Rack 12           2020/01/21                        NA
# 724   SAL_734   C4  Rack 12           2020/01/21                        NA
# 725   SAL_735   C4  Rack 12           2020/01/21                        NA
#
#     Environmental_Condition      Sex Lineage Transgenic_Line  \
# 0                   Aquatic   Female     NaN              WT
# 1                   Aquatic     Male     NaN              WT
# 2                   Aquatic     Male     NaN              WT
# 3                   Aquatic     Male     NaN              WT
# 4                   Aquatic     Male     NaN              WT
# ..                      ...      ...     ...             ...
# 721                 Aquatic  Unknown     NaN              WT
# 722                 Aquatic  Unknown     NaN              WT
# 723                 Aquatic   Female    fake              WT
# 724                 Aquatic   Female    fake              WT
# 725                 Aquatic   Female    fake              WT
#
#     Experimental_Holds               Species Protocol_Number  \
# 0             Breeding     Pleurodeles waltl        AABF2564
# 1             Breeding     Pleurodeles waltl        AABF2564
# 2             Breeding     Pleurodeles waltl        AABF2564
# 3             Breeding     Pleurodeles waltl        AABF2564
# 4             Breeding     Pleurodeles waltl        AABF2564
# ..                 ...                   ...             ...
# 721                 GG  Polypterus senegalus        AABY5655
# 722                NaN     Pleurodeles waltl        AABL1550
# 723         No history     Pleurodeles waltl        AABF2564
# 724         No history     Pleurodeles waltl        AABF2564
# 725         No history     Pleurodeles waltl        AABF2564
#
#     Experimental_History        RFID Date_of_Terra Date_of_Reaqua  Diet
# 0                    NaN         NaN           NaN            NaN   NaN
# 1                    NaN         NaN           NaN            NaN   NaN
# 2                    NaN         NaN           NaN            NaN   NaN
# 3                    NaN         NaN           NaN            NaN   NaN
# 4                    NaN         NaN           NaN            NaN   NaN
# ..                   ...         ...           ...            ...   ...
# 721                  NaN         NaN           NaN            NaN   NaN
# 722                  NaN         NaN           NaN            NaN   NaN
# 723                 rifd  2025-05-04    2025-04-03     Gummy diet  None
# 724                 rifd  2025-05-04    2025-04-03     Gummy diet  None
# 725                 rifd  2025-05-04    2025-04-03     Gummy diet  None
#
# [726 rows x 17 columns],     Animal_ID Tank     Rack                  DOB                    Cohort  \
# 0     SAL_003   C4  Rack 12                  NaN  Reptile Rapture - Yellow
# 1     SAL_004   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 2     SAL_005   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 3     SAL_006   C4  Rack 12              1/21/20  Reptile Rapture - Yellow
# 4     SAL_007   B4  Rack 12              1/21/20      Reptiles & Critters
# ..        ...  ...      ...                  ...                       ...
# 721   SAL_731   C3   Rack 1  2025-03-12 00:00:00                       NaN
# 722   SAL_732   A1   Rack 1                  NaN                       NaN
# 723   SAL_733   C4  Rack 12           2020/01/21                        NA
# 724   SAL_734   C4  Rack 12           2020/01/21                        NA
# 725   SAL_735   C4  Rack 12           2020/01/21                        NA
#
#     Environmental_Condition      Sex Lineage Transgenic_Line  \
# 0                   Aquatic   Female     NaN              WT
# 1                   Aquatic     Male     NaN              WT
# 2                   Aquatic     Male     NaN              WT
# 3                   Aquatic     Male     NaN              WT
# 4                   Aquatic     Male     NaN              WT
# ..                      ...      ...     ...             ...
# 721                 Aquatic  Unknown     NaN              WT
# 722                 Aquatic  Unknown     NaN              WT
# 723                 Aquatic   Female    fake              WT
# 724                 Aquatic   Female    fake              WT
# 725                 Aquatic   Female    fake              WT
#
#     Experimental_Holds               Species Protocol_Number  \
# 0             Breeding     Pleurodeles waltl        AABF2564
# 1             Breeding     Pleurodeles waltl        AABF2564
# 2             Breeding     Pleurodeles waltl        AABF2564
# 3             Breeding     Pleurodeles waltl        AABF2564
# 4             Breeding     Pleurodeles waltl        AABF2564
# ..                 ...                   ...             ...
# 721                 GG  Polypterus senegalus        AABY5655
# 722                NaN     Pleurodeles waltl        AABL1550
# 723         No history     Pleurodeles waltl        AABF2564
# 724         No history     Pleurodeles waltl        AABF2564
# 725         No history     Pleurodeles waltl        AABF2564
#
#     Experimental_History        RFID Date_of_Terra Date_of_Reaqua  Diet
# 0                    NaN         NaN           NaN            NaN   NaN
# 1                    NaN         NaN           NaN            NaN   NaN
# 2                    NaN         NaN           NaN            NaN   NaN
# 3                    NaN         NaN           NaN            NaN   NaN
# 4                    NaN         NaN           NaN            NaN   NaN
# ..                   ...         ...           ...            ...   ...
# 721                  NaN         NaN           NaN            NaN   NaN
# 722                  NaN         NaN           NaN            NaN   NaN
# 723                 rifd  2025-05-04    2025-04-03     Gummy diet  None
# 724                 rifd  2025-05-04    2025-04-03     Gummy diet  None
# 725                 rifd  2025-05-04    2025-04-03     Gummy diet  None
#
# [726 rows x 17 columns]]

# %%
R.euthanasia_log
# Out:
# [{'Animal_ID': 'SAL_002',
#   'Tank': 'C4',
#   'Rack': 'Rack 12',
#   'DOB': nan,
#   'Cohort': 'Reptile Rapture - Yellow',
#   'Environmental_Condition': 'Aquatic',
#   'Lineage': nan,
#   'Transgenic_Line': 'WT',
#   'Experimental_Holds': 'Breeding',
#   'Species': 'Pleurodeles waltl',
#   'Protocol_Number': 'AABF2564',
#   'Experimental_History': nan,
#   'RFID': nan,
#   'Date_of_Terra': nan,
#   'Date_of_Reaqua': nan,
#   'Diet': nan,
#   'DOD': '2025-05-10',
#   'Weight_g': 0.0,
#   'Sex': 'Female',
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan}]

# %%
R.save_inventory()
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.

# %%
R.save_state()

# %%
R.save_euthanasia_log()

# %%
R.undo()
# Out:
# History before undo: 3 states
# History after undo: 2 states
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.
# State saved: 3 states in history.
# Undo successful.
# True

# %%
R.move_salamander(["SAL_014", "SAL_015", "SAL_017", "SAL_019"], "Rack 8", "B4")
# Out:
# Animal SAL_014 moved to Rack 8.
# B4
# Log successful
# Animal SAL_015 moved to Rack 8.
# B4
# Log successful
# Animal SAL_017 moved to Rack 8.
# B4
# Log successful
# Animal SAL_019 moved to Rack 8.
# B4
# Log successful
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/notebooks/salamander_inventory.csv.

# %%
R.is_valid_tank("Rack 13", "D2")
# Out:
# False

# %%
R.edit_salamander_info(
    "SAL_005",
    **{
        "Environmental Condition": "Aquatic",  # Correct usage
        "Sex": "Female",
        "Protocol Number": "AABL",
        "Experimental History": "Behavioral Study"
    }
)
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/notebooks/salamander_inventory.csv.
# Log successful
# Updated SAL_005:
#  - Environmental Condition: Aquatic → Aquatic
#  - Sex: Male → Female
#  - Protocol Number: AABL → AABL
#  - Experimental History: Behavioral Study → Behavioral Study

# %%
print(R.inventory.columns.tolist())
# Out:
# ['Animal_ID', 'Tank', 'Rack', 'DOB', 'Environmental_Condition', 'Sex', 'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species', 'Protocol_Number', 'Experimental_History', 'RFID', 'Date_of_Terra', 'Date_of_Reaqua', 'Diet']

# %%
R.plot_rack_space()
#Build on this more - zooming in on one rack or one tank
#Maybe tie into search function
#maybe add color by species, by age range, by transgenic status, by no holds (change holds > who has hold or priority)

# %%
R.plot_transgenic_distribution()

# %%
#add larval euthanasia log?

# %%
R.search_salamanders(Species = "Pleurodeles waltl")
#returns hsyn as a partial match for all hsyn
#Add a summary of number of animals?
#Prints dataframe sometimes and prints plot sometimes - print both?
# Out:
#    Animal_ID Tank     Rack         DOB Environmental_Condition     Sex  \
# 4    SAL_006   C3   Rack 2  2022-01-16                  Reaqua     NaN
# 9    SAL_012   C3   Rack 2  2022-05-22                    Aqua     NaN
# 10   SAL_014   B4   Rack 8  2022-05-22                    Aqua     NaN
# 11   SAL_015   B4   Rack 8  2022-05-22                    Aqua     NaN
# 12   SAL_017   B4   Rack 8  2022-05-22                    Aqua  Female
# 13   SAL_019   B4   Rack 8  2022-05-22                    Aqua  Female
# 14   SAL_020   C2  Rack 10  2025-04-15             Terrestrial  Female
#
#    Lineage Transgenic_Line Experimental_Holds            Species  \
# 4   Sweden        Wildtype              False  Pleurodeles waltl
# 9      PxO           GCaMP                     Pleurodeles waltl
# 10     PxO           GCaMP                     Pleurodeles waltl
# 11     PxO           GCaMP                     Pleurodeles waltl
# 12     PxO    hsyn-GCamP6s                     Pleurodeles waltl
# 13     PxO    hsyn-GCamP6s                     Pleurodeles waltl
# 14  Sweden        hsyn-GFP               True  Pleurodeles waltl
#
#    Protocol_Number   Experimental_History
# 4             AABL  Behavior Conditioning
# 9         AABL1550                    NaN
# 10        AABL1550                    NaN
# 11        AABL1550                    NaN
# 12        AABL1550                    Edu
# 13        AABL1550                    Edu
# 14        AABL1550                     TS

# %%
criteria = {
    "Environmental Condition": "Aquatic",
    "Protocol Number": "AABL"
}
R.search_salamanders(**criteria)
#Options for fixing issue - if adding _ to colnames need to update in module where nececssary
#self.inventory.columns = [col.replace(" ", "_") for col in self.inventory.columns]
# Out:
#   Animal ID Tank    Rack         DOB Environmental Condition     Sex Lineage  \
# 0   SAL_001   B2  Rack 1  2021-09-05                 Aquatic     NaN  Sweden
# 3   SAL_005   C3  Rack 2  2024-06-21                 Aquatic  Female     YxO
#
#   Transgenic Line Experimental Holds               Species Protocol Number  \
# 0        hsyn-GFP              False  Polypterus senegalus            AABL
# 3         GCamP6s               True   Ambystoma mexicanum            AABL
#
#   Experimental History
# 0                  EdU
# 3     Behavioral Study

# %%
R.analyze_euthanasia_log()
#add by experimenter
# Out:
#   Protocol Number  Year  total_euthanized  complications
# 0        AABL1550  2025                 3              3

# %%
# Out:
# 'To add: '

# %%
summary = R.analyze_euthanasia_log()
print(summary)
# Out:
#   Protocol Number  Year  total_euthanized  complications
# 0        AABL1550  2025                 2              2

# %%
R.inventory.rename(columns={"Experimental History": "Experimental_History", "Transgenic Line": "Transgenic_Line"}, inplace=True)

# %%
log = pd.read_csv("euthanasia_log.csv")

# %%
inv = pd.read_csv("salamander_inventory.csv")

# %%
R.inventory["Diet"] = None

# %%
column_rename_map = {
    "Animal ID": "Animal_ID",
    "DOB": "DOB",
    "Tank": "Tank",
    "Rack": "Rack",
    "Environmental Condition": "Environmental_Condition",
    "Lineage": "Lineage",
    "Transgenic Line": "Transgenic_Line",
    "Experimental Holds": "Experimental_Holds",
    "Species": "Species",
    "Protocol Number": "Protocol_Number",
    "Experimental History": "Experimental_History",
    "DOD": "DOD",
    "Weight (g)": "Weight_g",
    "Sex": "Sex",
    "Purpose": "Purpose",
    "Experimenter": "Experimenter",
    "Complications": "Complications"
}
log.rename(columns=column_rename_map, inplace=True)

# %%
print(R.inventory.columns.tolist())
# Out:
# ['Animal_ID', 'Tank', 'Rack', 'DOB', 'Environmental_Condition', 'Sex', 'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species', 'Protocol_Number', 'Experimental_History', 'RFID', 'Date_of_Terra', 'Date_of_Reaqua', 'Diet']

# %%
R.inventory.rename(columns={
    "RFID_Tag": "RFID",
    "RFID": "Date_of_Terra",
}, inplace=True)

# %%
R.save_inventory()
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.

# %%
log = log.iloc[:, :17]

# %%
log.to_csv("euthanasia_log.csv", index=False)

# %%
log = log.drop(index=2)

# %%
#R.euthanasia_log = []  # Clear in-memory log
R.save_euthanasia_log()

# %%
pd.DataFrame(columns=["Animal_ID", "Tank", "Rack", "DOB", "Cohort", "Environmental_Condition", "Lineage", 
                      "Transgenic_Line", "Experimental_Holds", "Species", "Protocol_Number", 
                      "Experimental_History", "DOD", "Weight_g", "Sex", "Purpose", 
                      "Experimenter", "Complications"]).to_csv("euthanasia_log.csv", index=False)

# %%
df = pd.read_csv("euthanasia_log.csv")

# %%
df.insert(loc=df.columns.get_loc("DOB") + 1, column="Cohort", value=None)

# %%
df.to_csv("euthanasia.csv", index=False)

# %%
print(df.columns)
# Out:
# Index(['Animal_ID', 'Tank', 'Rack', 'DOB', 'Cohort', 'Environmental_Condition',
#        'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species',
#        'Protocol_Number', 'Experimental_History', 'DOD', 'Weight_g', 'Sex',
#        'Purpose', 'Experimenter', 'Complications', 'RFID', 'Date_of_Terra',
#        'Date_of_Reaqua', 'Diet'],
#       dtype='object')

# %%
print(R.inventory.columns)
# Out:
# Index(['Animal_ID', 'Tank', 'Rack', 'DOB', 'Cohort', 'Environmental_Condition',
#        'Sex', 'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species',
#        'Protocol_Number', 'Experimental_History', 'RFID', 'Date_of_Terra',
#        'Date_of_Reaqua', 'Diet'],
#       dtype='object')

# %%
# Clear the DataFrame and euthanasia log list
R.inventory = pd.DataFrame(columns=R.inventory.columns)
R.euthanasia_log = pd.DataFrame(columns=df.columns)

# %%
# Save cleared data to disk
R.save_inventory()
R.save_euthanasia_log()
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.

# %%
# log the reset
R.log_change("Reset", "Cleared inventory and euthanasia log to start generating real inventory")

# %%
print(f"{pd.DataFrame(R.euthanasia_log).columns}")
# Out:
# Index(['Animal_ID', 'Tank', 'Rack', 'DOB', 'Cohort', 'Environmental_Condition',
#        'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species',
#        'Protocol_Number', 'Experimental_History', 'DOD', 'Weight_g', 'Sex',
#        'Purpose', 'Experimenter', 'Complications', 'RFID', 'Date_of_Terra',
#        'Date_of_Reaqua', 'Diet'],
#       dtype='object')

# %%
"""To do: 
-organize github folder
Animals that arent euthanized but not in inventory
- add list of animals donated to other labs (edited)
# Out:
# 'To do: \n-update main\n\n-Add clutch function\n- add larval euthansia log and expand analyze euth tab to include larvae\nAnimals that arent euthanized but not in inventory\n- add list of animals donated to other labs\n'

# %%
"""Streamlit things:
-Deploy with lab github, ask Nicholas to help set up on workstation
-put limits on who can undo changes by other users

# %%
"""Done today: 
Changelog - reverse display order for viewing
-allow custom message for log
-'Add clutch' function
-save clutch_file function
-Add larval clutches and larval euthanasia log to view files tab
-fixed larval euthanasia function
Clutches added in MM/DD/YYYY
-Undo button successfully updates new larvae logs - add clutch/larval euth
-Analyze euthanasia log includes larval log analysis, date conversions work
-User guide tab
-Euthanize function dropdown was autopopulating to next animal if animal no longer exists 
  default to "Select Animal ID"
-Password and initials necessary - changelog records initials with actions
"""
# Out:
# 'Done today: \nUndo - can now go back multiple states, doesnt always remove a euthanasia log row\nPrints animal indexes after addition instead of just tank added to\nundo function in sidebar so easily accessible after any action\nSAL_ID added in search\nThicker lines to demarcate rows\nanimal ids metadata printed after moving animals\nrack comes before tank in csv\nselectbox for euthanize tab\nAdded larval clutches file - dob dropdown for add_salamander()\n'

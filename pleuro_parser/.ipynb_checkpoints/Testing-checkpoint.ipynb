# %%
import sys
sys.path.append('..')
import module
import pandas as pd

# %%
R = module.Rack(inventory_file = "salamander_inventory.csv", filename = "current.csv", csv_file = "salamander_inventory.csv")
# Out:
# Loaded existing inventory from salamander_inventory.csv
# State is saving to current.csv

# %%
R.inventory
# Out:
#    Animal ID Tank    Rack         DOB Environmental Condition   Sex  \
# 0    SAL_001    1  Rack 2  2021-09-05                 Aquatic   NaN
# 1    SAL_002    7  Rack 3  2024-02-03             Terrestrial   NaN
# 2    SAL_003    7  Rack 2  2022-02-09             Terrestrial   NaN
# 3    SAL_005    4  Rack 3  2024-06-21             Terrestrial   NaN
# 4    SAL_006    4  Rack 3  2022-01-16                  Reaqua   NaN
# 5    SAL_007   10  Rack 3  2024-01-22                  Reaqua   NaN
# 6    SAL_008    2  Rack 3  2020-07-19                  Reaqua   NaN
# 7    SAL_009    4  Rack 2  2024-02-02                  Reaqua   NaN
# 8    SAL_010    9  Rack 3  2023-06-12                 Aquatic   NaN
# 9    SAL_011   A5  Rack 3  2022-05-22                    Aqua   NaN
# 10   SAL_012   A5  Rack 3  2022-05-22                    Aqua   NaN
# 11   SAL_013   A5  Rack 3  2022-05-22                    Aqua   NaN
# 12   SAL_014   A5  Rack 3  2022-05-22                    Aqua   NaN
# ...

# %%
#Not sure why duplicate animal Ids detected, but fixed duplication to add error and change animal id if duplicated
R.add_salamanders(5, '2022-05-22', "Pleurodeles waltl", "GCaMP", "PxO", "AABL1550", "Rack 3", "A5", "Aqua", "Unknown", " ", "Edu")
# Out:
# Error: Default sex to NaN
# 5 new salamander(s) adding successfully.
# Error: Duplicate Animal IDs detected. Editing new IDs

# %%
#Fixed so only animals that exist can be removed 
R.euthanize_animal('SAL_011','2025-3-6', 9, "Female", "Histology", "AOG", complications="None")
# Out:
# Animal SAL_011 euthanized and removed from inventory.

# %%
#Can't change file to save to (not sure if
R.save_inventory()
# Out:
# Inventory saved to salamander_inventory.csv.

# %%
#I dont know where the history saves???
R.save_state()
# Out:
# State is saving to current.csv

# %%
#This is working!! - need to do R.save_state after edit to have state to revert to 
#To do - automatically save state after edits so undo can be used immediately?
#Can now undo multiple changes as long as state is saved between edits 
R.undo()
# Out:
# Undo successful: reverted to previous state.

# %%
#Requires manually typing action/details 
#Only one action at a time
#To do- allow mulitple actions, maybe automatic tracking??

R.log_change("Added animals", "5 animals added to Rack 3")

# %%
#Only changes rack
#To do: Allow only Tank change & Rack/Tank change
R.move_salamander(["SAL_002"], "Rack 5")
# Out:
# Animal SAL_002 moved to Rack 5.

# %%
#To do: Empty racks not showing up 
#Tank names not consistent - set options for tank numbers (A5 doesnt show up)
R.plot_rack_space()

# %%
R.plot_transgenic_distribution()

# %%
"""To add: 
-protocol tracking 
-fix search function
-add function to edit animal history
-add more plotting features?
-update readme
"""
# Out:
# 'To add: '

# %%
if "Transgenic Status" in R.inventory.columns:
    R.inventory.rename(columns={"Transgenic Status": "Transgenic Line"}, inplace=True)

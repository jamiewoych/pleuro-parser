# %%
import sys
sys.path.append('..')
import module
import pandas as pd

# %%
R = module.Rack(inventory_file = "salamander_inventory.csv", filename = "current.csv", euthanasia_log_file = "euthanasia_log.csv")
# Out:
# Temporary session directory created at <TemporaryDirectory '/var/folders/qk/0pp_4zdn44s_7tprcl4npjfw0000gn/T/tmpf_3i_lre'>
# Loaded existing inventory from salamander_inventory.csv

# %%
R.plot_rack_space()

# %%
R.inventory
# Out:
# Empty DataFrame
# Columns: [Animal_ID, Tank, Rack, DOB, Cohort, Environmental_Condition, Sex, Lineage, Transgenic_Line, Experimental_Holds, Species, Protocol_Number, Experimental_History, RFID, Date_of_Terra, Date_of_Reaqua, Diet]
# Index: []

# %%
R.add_salamanders(3, "2020/01/21", "Pleurodeles waltl", "WT", "", "AABF2564", "Rack 12", "C4", "Aquatic", "Female")
# Out:
# /Users/jamie/hacks/pleuro-parser/pleuro_parser/module.py:154: SyntaxWarning: invalid escape sequence '\d'
#   """
# /Users/jamie/hacks/pleuro-parser/pleuro_parser/module.py:436: SyntaxWarning: invalid escape sequence '\s'
#   log_df["Experimenter_List"] = log_df["Experimenter"].str.split(",\s*")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 R.add_salamanders(3, "2020/01/21", "Pleurodeles waltl", "WT", "", "AABF2564", "Rack 12", "C4", "Aquatic", "Female")
#
# File ~/hacks/pleuro-parser/pleuro_parser/module.py:158, in Rack.add_salamanders(self, num_salamanders, dob, species, transgenic_line, lineage, protocol, rack, tank, env_condition, sex, experimental_holds, experimental_history, rfid, terra_date, aqua_date, diet)
#     151     print(f"Error: Tank {tank} on {rack} is blocked for use.")
#     152     return
#     154 """
#     155 # Handle empty euthanasia log by checking before performing operations
#     156 if not self.euthanasia_log:  # Euthanasia log is empty
#     157     old_ids = pd.DataFrame()  # Initialize an empty DataFrame
# --> 158 else:
#     159     old_ids = pd.DataFrame(self.euthanasia_log)["Animal_ID"].str.extract(r"SAL_(\d+)").dropna().astype(int) # already used and in euthanasia log
#     160 """
#     162 # Handle empty inventory for first time initializing
#     163 if self.inventory.empty:
#     164     # Initialize the inventory DataFrame with columns, no rows
#
# File /opt/anaconda3/envs/uris329/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/uris329/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Animal_ID'

# %%
R.euthanize_animal('SAL_002','2025-4-12', 9, "Male", "Histology", "AOG", complications="found dead")
# Out:
# Log successful
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.
# Animal SAL_002 euthanized and removed from inventory.

# %%
R.euthanasia_log
# Out:
# [{'Animal_ID': 'SAL_016',
#   'Tank': 'A5',
#   'Rack': 'Rack 3',
#   'DOB': '2022-05-22',
#   'Environmental_Condition': 'Aqua',
#   'Lineage': 'PxO',
#   'Transgenic_Line': 'hsyn-GCamP6s',
#   'Experimental_Holds': ' ',
#   'Species': 'Pleurodeles waltl',
#   'Protocol_Number': 'AABL1550',
#   'Experimental_History': 'Edu',
#   'DOD': '2025-4-12',
#   'Weight_g': 9.0,
#   'Sex': 'Male',
#   'Purpose': 'Histology',
#   'Experimenter': 'AOG',
#   'Complications': 'found dead'},
#  {'Animal_ID': 'SAL_013',
#   'Tank': 'A5',
#   'Rack': 'Rack 3',
#   'DOB': '2022-05-22',
#   'Environmental_Condition': 'Aqua',
#   'Lineage': 'PxO',
#   'Transgenic_Line': 'GCaMP',
#   'Experimental_Holds': ' ',
#   'Species': 'Pleurodeles waltl',
#   'Protocol_Number': 'AABL1550',
#   'Experimental_History': nan,
#   'DOD': '2025-4-12',
#   'Weight_g': 9.0,
#   'Sex': 'Male',
#   'Purpose': 'Histology',
#   'Experimenter': 'AOG',
#   'Complications': 'found dead'},
#  {'Animal_ID': 'SAL_018',
#   'Tank': 'A6',
#   'Rack': 'Rack 5',
#   'DOB': '2022-05-22',
#   'Environmental_Condition': 'Aqua',
#   'Lineage': 'PxO',
#   'Transgenic_Line': 'hsyn-GCamP6s',
#   'Experimental_Holds': ' ',
#   'Species': 'Pleurodeles waltl',
#   'Protocol_Number': 'AABL1550',
#   'Experimental_History': 'Edu',
#   'DOD': '2025-4-12',
#   'Weight_g': 9.0,
#   'Sex': 'Male',
#   'Purpose': 'Histology',
#   'Experimenter': 'AOG',
#   'Complications': 'found dead'},
#  {'Animal_ID': 'SAL_003',
#   'Tank': 'B2',
#   'Rack': 'Rack 1',
#   'DOB': '2022-02-09',
#   'Environmental_Condition': 'Terrestrial',
#   'Lineage': 'Sweden',
#   'Transgenic_Line': 'Wildtype',
#   'Experimental_Holds': 'True',
#   'Species': 'Polypterus senegalus',
#   'Protocol_Number': 'AABI',
#   'Experimental_History': 'Behavior Conditioning',
#   'DOD': '2025-04-23',
#   'Weight_g': nan,
#   'Sex': nan,
#   'Purpose': 'revamping inventory',
#   'Experimenter': 'JW',
#   'Complications': nan},
#  {'Animal_ID': 'SAL_005',
#   'Tank': 'C3',
#   'Rack': 'Rack 2',
#   'DOB': '2024-06-21',
#   'Environmental_Condition': 'Aquatic',
#   'Lineage': 'YxO',
#   'Transgenic_Line': 'GCamP6s',
#   'Experimental_Holds': 'True',
#   'Species': 'Ambystoma mexicanum',
#   'Protocol_Number': 'AABL',
#   'Experimental_History': 'Behavioral Study',
#   'DOD': '2025-04-23',
#   'Weight_g': nan,
#   'Sex': 'Female',
#   'Purpose': 'revamping inventory',
#   'Experimenter': 'JW',
#   'Complications': nan},
#  {'Animal_ID': 'SAL_006',
#   'Tank': 'C3',
#   'Rack': 'Rack 2',
#   'DOB': '2022-01-16',
#   'Environmental_Condition': 'Reaqua',
#   'Lineage': 'Sweden',
#   'Transgenic_Line': 'Wildtype',
#   'Experimental_Holds': 'False',
#   'Species': 'Pleurodeles waltl',
#   'Protocol_Number': 'AABL',
#   'Experimental_History': 'Behavior Conditioning',
#   'DOD': '2025-04-23',
#   'Weight_g': 0.0,
#   'Sex': nan,
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan},
#  {'Animal_ID': 'SAL_002',
#   'Tank': 'B2',
#   'Rack': 'Rack 1',
#   'DOB': '2024-02-03',
#   'Environmental_Condition': 'Terrestrial',
#   'Lineage': 'YxO',
#   'Transgenic_Line': 'GCamP6s',
#   'Experimental_Holds': 'False',
#   'Species': 'Polypterus senegalus',
#   'Protocol_Number': 'AABY',
#   'Experimental_History': 'EdU',
#   'DOD': '2025-04-23',
#   'Weight_g': 0.0,
#   'Sex': nan,
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan},
#  {'Animal_ID': 'SAL_002',
#   'Tank': 'B2',
#   'Rack': 'Rack 1',
#   'DOB': '2024-02-03',
#   'Environmental_Condition': 'Terrestrial',
#   'Lineage': 'YxO',
#   'Transgenic_Line': 'GCamP6s',
#   'Experimental_Holds': 'False',
#   'Species': 'Polypterus senegalus',
#   'Protocol_Number': 'AABY',
#   'Experimental_History': 'EdU',
#   'DOD': '2025-04-23',
#   'Weight_g': 0.0,
#   'Sex': nan,
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan},
#  {'Animal_ID': 'SAL_002',
#   'Tank': 'B2',
#   'Rack': 'Rack 1',
#   'DOB': '2024-02-03',
#   'Environmental_Condition': 'Terrestrial',
#   'Lineage': 'YxO',
#   'Transgenic_Line': 'GCamP6s',
#   'Experimental_Holds': 'False',
#   'Species': 'Polypterus senegalus',
#   'Protocol_Number': 'AABY',
#   'Experimental_History': 'EdU',
#   'DOD': '2025-04-23',
#   'Weight_g': 0.0,
#   'Sex': nan,
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan},
#  {'Animal_ID': 'SAL_002',
#   'Tank': 'B2',
#   'Rack': 'Rack 1',
#   'DOB': '2024-02-03',
#   'Environmental_Condition': 'Terrestrial',
#   'Lineage': 'YxO',
#   'Transgenic_Line': 'GCamP6s',
#   'Experimental_Holds': 'False',
#   'Species': 'Polypterus senegalus',
#   'Protocol_Number': 'AABY',
#   'Experimental_History': 'EdU',
#   'DOD': '2025-04-23',
#   'Weight_g': 0.0,
#   'Sex': nan,
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan},
#  {'Animal_ID': 'SAL_007',
#   'Tank': 'D2',
#   'Rack': 'Rack 12',
#   'DOB': '2024-01-22',
#   'Environmental_Condition': 'Reaqua',
#   'Lineage': 'Jungle Bobs',
#   'Transgenic_Line': 'Wildtype',
#   'Experimental_Holds': 'True',
#   'Species': 'Polypterus senegalus',
#   'Protocol_Number': 'AABL',
#   'Experimental_History': 'Regeneration',
#   'DOD': '2025-04-23',
#   'Weight_g': 0.0,
#   'Sex': nan,
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan},
#  {'Animal_ID': 'SAL_008',
#   'Tank': 'D2',
#   'Rack': 'Rack 12',
#   'DOB': '2020-07-19',
#   'Environmental_Condition': 'Reaqua',
#   'Lineage': 'Jungle Bobs',
#   'Transgenic_Line': 'hsyn-GFP',
#   'Experimental_Holds': 'True',
#   'Species': 'Ambystoma mexicanum',
#   'Protocol_Number': 'AABI',
#   'Experimental_History': 'Viral injection',
#   'DOD': '2025-04-23',
#   'Weight_g': 0.0,
#   'Sex': nan,
#   'Purpose': nan,
#   'Experimenter': nan,
#   'Complications': nan}]

# %%
R.save_inventory()
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.

# %%
R.save_state()

# %%
R.save_euthanasia_log()

# %%
R.undo()
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.
# Undo successful.
# Log successful
# Undo successful.

# %%
R.move_salamander(["SAL_014", "SAL_015", "SAL_017", "SAL_019"], "Rack 8", "B4")
# Out:
# Animal SAL_014 moved to Rack 8.
# B4
# Log successful
# Animal SAL_015 moved to Rack 8.
# B4
# Log successful
# Animal SAL_017 moved to Rack 8.
# B4
# Log successful
# Animal SAL_019 moved to Rack 8.
# B4
# Log successful
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/notebooks/salamander_inventory.csv.

# %%
R.is_valid_tank("Rack 13", "D2")
# Out:
# False

# %%
R.edit_salamander_info(
    "SAL_005",
    **{
        "Environmental Condition": "Aquatic",  # Correct usage
        "Sex": "Female",
        "Protocol Number": "AABL",
        "Experimental History": "Behavioral Study"
    }
)
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/notebooks/salamander_inventory.csv.
# Log successful
# Updated SAL_005:
#  - Environmental Condition: Aquatic → Aquatic
#  - Sex: Male → Female
#  - Protocol Number: AABL → AABL
#  - Experimental History: Behavioral Study → Behavioral Study

# %%
print(R.inventory.columns.tolist())
# Out:
# ['Animal_ID', 'Tank', 'Rack', 'DOB', 'Environmental_Condition', 'Sex', 'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species', 'Protocol_Number', 'Experimental_History', 'RFID', 'Date_of_Terra', 'Date_of_Reaqua', 'Diet']

# %%
R.plot_rack_space()
#Build on this more - zooming in on one rack or one tank
#Maybe tie into search function
#maybe add color by species, by age range, by transgenic status, by no holds (change holds > who has hold or priority)

# %%
R.plot_transgenic_distribution()

# %%
#add larval euthanasia log?

# %%
R.search_salamanders(Species = "Pleurodeles waltl")
#returns hsyn as a partial match for all hsyn
#Add a summary of number of animals?
#Prints dataframe sometimes and prints plot sometimes - print both?
# Out:
#    Animal_ID Tank     Rack         DOB Environmental_Condition     Sex  \
# 4    SAL_006   C3   Rack 2  2022-01-16                  Reaqua     NaN
# 9    SAL_012   C3   Rack 2  2022-05-22                    Aqua     NaN
# 10   SAL_014   B4   Rack 8  2022-05-22                    Aqua     NaN
# 11   SAL_015   B4   Rack 8  2022-05-22                    Aqua     NaN
# 12   SAL_017   B4   Rack 8  2022-05-22                    Aqua  Female
# 13   SAL_019   B4   Rack 8  2022-05-22                    Aqua  Female
# 14   SAL_020   C2  Rack 10  2025-04-15             Terrestrial  Female
#
#    Lineage Transgenic_Line Experimental_Holds            Species  \
# 4   Sweden        Wildtype              False  Pleurodeles waltl
# 9      PxO           GCaMP                     Pleurodeles waltl
# 10     PxO           GCaMP                     Pleurodeles waltl
# 11     PxO           GCaMP                     Pleurodeles waltl
# 12     PxO    hsyn-GCamP6s                     Pleurodeles waltl
# 13     PxO    hsyn-GCamP6s                     Pleurodeles waltl
# 14  Sweden        hsyn-GFP               True  Pleurodeles waltl
#
#    Protocol_Number   Experimental_History
# 4             AABL  Behavior Conditioning
# 9         AABL1550                    NaN
# 10        AABL1550                    NaN
# 11        AABL1550                    NaN
# 12        AABL1550                    Edu
# 13        AABL1550                    Edu
# 14        AABL1550                     TS

# %%
criteria = {
    "Environmental Condition": "Aquatic",
    "Protocol Number": "AABL"
}
R.search_salamanders(**criteria)
#Options for fixing issue - if adding _ to colnames need to update in module where nececssary
#self.inventory.columns = [col.replace(" ", "_") for col in self.inventory.columns]
# Out:
#   Animal ID Tank    Rack         DOB Environmental Condition     Sex Lineage  \
# 0   SAL_001   B2  Rack 1  2021-09-05                 Aquatic     NaN  Sweden
# 3   SAL_005   C3  Rack 2  2024-06-21                 Aquatic  Female     YxO
#
#   Transgenic Line Experimental Holds               Species Protocol Number  \
# 0        hsyn-GFP              False  Polypterus senegalus            AABL
# 3         GCamP6s               True   Ambystoma mexicanum            AABL
#
#   Experimental History
# 0                  EdU
# 3     Behavioral Study

# %%
R.analyze_euthanasia_log()
#add by experimenter
# Out:
#   Protocol Number  Year  total_euthanized  complications
# 0        AABL1550  2025                 3              3

# %%
# Out:
# 'To add: '

# %%
summary = R.analyze_euthanasia_log()
print(summary)
# Out:
#   Protocol Number  Year  total_euthanized  complications
# 0        AABL1550  2025                 2              2

# %%
R.inventory.rename(columns={"Experimental History": "Experimental_History", "Transgenic Line": "Transgenic_Line"}, inplace=True)

# %%
log = pd.read_csv("euthanasia_log.csv")

# %%
inv = pd.read_csv("salamander_inventory.csv")

# %%
R.inventory["Diet"] = None

# %%
column_rename_map = {
    "Animal ID": "Animal_ID",
    "DOB": "DOB",
    "Tank": "Tank",
    "Rack": "Rack",
    "Environmental Condition": "Environmental_Condition",
    "Lineage": "Lineage",
    "Transgenic Line": "Transgenic_Line",
    "Experimental Holds": "Experimental_Holds",
    "Species": "Species",
    "Protocol Number": "Protocol_Number",
    "Experimental History": "Experimental_History",
    "DOD": "DOD",
    "Weight (g)": "Weight_g",
    "Sex": "Sex",
    "Purpose": "Purpose",
    "Experimenter": "Experimenter",
    "Complications": "Complications"
}
log.rename(columns=column_rename_map, inplace=True)

# %%
print(R.inventory.columns.tolist())
# Out:
# ['Animal_ID', 'Tank', 'Rack', 'DOB', 'Environmental_Condition', 'Sex', 'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species', 'Protocol_Number', 'Experimental_History', 'RFID', 'Date_of_Terra', 'Date_of_Reaqua', 'Diet']

# %%
R.inventory.rename(columns={
    "RFID_Tag": "RFID",
    "RFID": "Date_of_Terra",
}, inplace=True)

# %%
R.save_inventory()
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.

# %%
log = log.iloc[:, :17]

# %%
log.to_csv("euthanasia_log.csv", index=False)

# %%
log = log.drop(index=2)

# %%
#R.euthanasia_log = []  # Clear in-memory log
R.save_euthanasia_log()

# %%
pd.DataFrame(columns=["Animal_ID", "Tank", "Rack", "DOB", "Cohort", "Environmental_Condition", "Lineage", 
                      "Transgenic_Line", "Experimental_Holds", "Species", "Protocol_Number", 
                      "Experimental_History", "DOD", "Weight_g", "Sex", "Purpose", 
                      "Experimenter", "Complications"]).to_csv("euthanasia_log.csv", index=False)

# %%
df = pd.read_csv("euthanasia_log.csv")

# %%
df.insert(loc=df.columns.get_loc("DOB") + 1, column="Cohort", value=None)

# %%
df.to_csv("euthanasia.csv", index=False)

# %%
print(df.columns)
# Out:
# Index(['Animal_ID', 'Tank', 'Rack', 'DOB', 'Cohort', 'Environmental_Condition',
#        'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species',
#        'Protocol_Number', 'Experimental_History', 'DOD', 'Weight_g', 'Sex',
#        'Purpose', 'Experimenter', 'Complications', 'RFID', 'Date_of_Terra',
#        'Date_of_Reaqua', 'Diet'],
#       dtype='object')

# %%
print(R.inventory.columns)
# Out:
# Index(['Animal_ID', 'Tank', 'Rack', 'DOB', 'Cohort', 'Environmental_Condition',
#        'Sex', 'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species',
#        'Protocol_Number', 'Experimental_History', 'RFID', 'Date_of_Terra',
#        'Date_of_Reaqua', 'Diet'],
#       dtype='object')

# %%
# Clear the DataFrame and euthanasia log list
R.inventory = pd.DataFrame(columns=R.inventory.columns)
R.euthanasia_log = pd.DataFrame(columns=df.columns)

# %%
# Save cleared data to disk
R.save_inventory()
R.save_euthanasia_log()
# Out:
# Inventory saved to /Users/jamie/hacks/pleuro-parser/pleuro_parser/salamander_inventory.csv.

# %%
# log the reset
R.log_change("Reset", "Cleared inventory and euthanasia log to start generating real inventory")

# %%
print(f"{pd.DataFrame(R.euthanasia_log).columns}")
# Out:
# Index(['Animal_ID', 'Tank', 'Rack', 'DOB', 'Cohort', 'Environmental_Condition',
#        'Lineage', 'Transgenic_Line', 'Experimental_Holds', 'Species',
#        'Protocol_Number', 'Experimental_History', 'DOD', 'Weight_g', 'Sex',
#        'Purpose', 'Experimenter', 'Complications', 'RFID', 'Date_of_Terra',
#        'Date_of_Reaqua', 'Diet'],
#       dtype='object')

# %%
"""To do: 
-update main

Future things:
for larvae 
- include clutches to choose from for add salamander
- add larval euthansia log and expand analyze euth tab to include larvae
Animals that arent euthanized but not in inventory
- add list of animals donated to other labs
"""
#Maybe define limited, full, blocked tanks/racks in init
# Out:
# 'To do: \n-generate a real inventory\n-update readme/main\n-add more tabs! \n    move animals \n    edit info\n    analyze euthanasia log\n\nplots - zoom in on specific rack\n    add tank search that allows multiple tanks to be printed in df\nfor larvae - include clutches \n'

# %%
"""Streamlit things:
-Require password & have changelog append name of person to logs
-Deploy with lab github, ask Nicholas to help set up on workstation

# %%
"""Done today: 
print summary of number of animals in search 
add new rack - off rack for surgical recovery and treatment, called rack 13 because of the way i index for plot
Reset the inventory and generated real inventory - including some fake animals for testing, as placeholders for missing indices
updated README for presentation
